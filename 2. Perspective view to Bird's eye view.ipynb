# %%
import cv2
import cv2 as cv
from operator import itemgetter
from glob import glob
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### right pavement

# %%
paper = cv2.imread(r'D:\DS\Python\Praxis\CAPP\VideoToImageData\frame0.jpg')

# Coordinates that you want to Perspective Transform
pts1 = np.float32([[1803,0],[1891,183],[603,1080],[1683,1080]])

# Size of the Transformed Image
pts2 = np.float32([[0,0],[1920,0],[0,1080],[1920,1080]])

plt.imshow(paper)
plt.show()

# %%
paper.shape
# Out:
# (1080, 1920, 3)

# %%
M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(paper,M,(1920,1080))
plt.imshow(dst)
plt.show()

# %%
dst.shape
# Out:
# (1080, 1920, 3)

# %% [markdown]
# #### road

# %%
paper = cv2.imread(r'D:\DS\Python\Praxis\CAPP\VideoToImageData\frame0.jpg')

# Coordinates that you want to Perspective Transform
pts1 = np.float32([[1410,0],[1803,0],[0,844],[603,1080]])

# Size of the Transformed Image
pts2 = np.float32([[0,0],[1920,0],[0,1080],[1920,1080]])

#plt.imshow(paper)
#plt.show()

# %%
M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(paper,M,(1920,1080))
plt.imshow(dst)
plt.show()

# %% [markdown]
# #### left pavement

# %%
paper = cv2.imread(r'D:\DS\Python\Praxis\CAPP\VideoToImageData\frame0.jpg')

# Coordinates that you want to Perspective Transform
pts1 = np.float32([[900,0],[1410,0],[0,510],[20,950]])

# Size of the Transformed Image
pts2 = np.float32([[0,0],[1920,0],[0,1080],[1920,1080]])

#plt.imshow(paper)
#plt.show()

# %%
M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(paper,M,(1920,1080))
plt.imshow(dst)
plt.show()

# %% [markdown]
# #### road and right pavement

# %%
paper = cv2.imread(r'D:\DS\Python\Praxis\CAPP\VideoToImageData\frame0.jpg')

# Coordinates that you want to Perspective Transform
pts1 = np.float32([[1335,0],[1891,183],[0,900],[1683,1080]])

# Size of the Transformed Image
pts2 = np.float32([[0,0],[1920,0],[0,1080],[1920,1080]])

#plt.imshow(paper)
#plt.show()

# %%
M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(paper,M,(1920,1080))
plt.imshow(dst)
plt.show()

# %%
plt.imshow(paper)
plt.show()

# %% [markdown]
# #### Trials with GN sir

# %%
paper = cv2.imread(r'D:\DS\Python\Praxis\CAPP\VideoToImageData\frame0.jpg')

# Coordinates that you want to Perspective Transform
pts1 = np.float32([[1254,-0.1],[1916,-0.1],[3,879],[1920,1072]])

# Size of the Transformed Image
pts2 = np.float32([[0,0],[1920,0],[0,1080],[1920,1080]])

#plt.imshow(paper)
#plt.show()

# %%
M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(paper,M,(1920,1080))
plt.imshow(dst)
plt.show()

# %%
paper = cv2.imread(r'D:\DS\Python\Praxis\CAPP\VideoToImageData\frame0.jpg')

# Coordinates that you want to Perspective Transform
pts1 = np.float32([[1060,-0.1],[1916,-0.1],[3,879],[1920,1072]])

# Size of the Transformed Image
pts2 = np.float32([[0,0],[1920,0],[0,1080],[1920,1080]])

#plt.imshow(paper)
#plt.show()

# %%
M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(paper,M,(1920,1080))
plt.imshow(dst)
plt.show()

# %% [markdown]
# #### Final coordinates considered

# %%
paper = cv2.imread(r'D:\DS\Python\Praxis\CAPP\VideoToImageData\frame0.jpg')

# Coordinates that you want to Perspective Transform
pts1 = np.float32([[1040,-0.1],[1916,-0.1],[3,879],[1920,1072]])

# Size of the Transformed Image
pts2 = np.float32([[0,0],[1920,0],[0,1080],[1920,1080]])

#plt.imshow(paper)
#plt.show()

M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(paper,M,(1920,1080))
plt.imshow(dst)
plt.show()

# %%
#original image
plt.imshow(paper)
plt.show()

# %%
#Rotation

def rotate(img, angle, rotPoint=None):
    (height,width) = img.shape[:2]
    
    if rotPoint is None:
        rotPoint = (width//2, height//2) #centre as the rotation point
       
    rotMat = cv.getRotationMatrix2D(rotPoint, angle, 1.0)
    dimensions = (width,height)
    
    return cv.warpAffine(img, rotMat, dimensions)
